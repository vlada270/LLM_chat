# %%
import os

# %%
# !pip install -U langchain langsmith
# !pip install datasets
# !pip install langchain_openai
# !pip install langchain_community
# !pip install ragas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 13.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.0 MB/s eta 0:00:00
# ...

# %%
from langchain.smith import RunEvalConfig, run_on_dataset

# %%
import os
import nest_asyncio
import pandas as pd
from langsmith import Client
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.smith import RunEvalConfig, run_on_dataset

# %%
os.environ['LANGCHAIN_ENDPOINT']="https://api.smith.langchain.com"
os.environ['LANGCHAIN_API_KEY']="API-KEY"
os.environ['OPENAI_API_KEY']="API-KEY"

# %%
client = Client()

llm = ChatOpenAI()
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
os.environ['LANGCHAIN_TRACING_V2']='true'
os.environ['LANGCHAIN_ENDPOINT']="https://api.smith.langchain.com"
os.environ['LANGCHAIN_API_KEY']="API-KEY"
os.environ['LANGCHAIN_PROJECT']="evaluation"

# %%
#data_samples = pd.read_csv('/content/Transformed_Data (1).csv')

# %%
data_samples = {
    'question': [
        'What exams should I take to apply for Applied Mathematics and Informatics program?',
        'Send me the link to the page with all programs.',
        'My budget is 600,000 rubles. Can you recommend mathematics programs within this amount?',
        'What is the goal of the mathematical preparation program?',
        'What kind of real projects do students participate in?',
        'What is the minimum score needed in Mathematics for admission?',
        'How do math and software support information processing?',
        'What is the purpose of the General Education Subject?',
        'What is the goal of the mathematical preparation program?',
        'What kind of real projects do students participate in?',
        'What is the minimum score needed in Mathematics for admission?',
        'How do math and software support information processing?',
        'What is the purpose of the General Education Subject?',
        'What fields can students work in after completing the Applied Mathematics program?',
        'What real-world problems do students solve in the Applied Mathematics program?',
        'What is the basis for the "Design" program at the School of Design at the National Research University Higher School of Economics?',
        'What exams should I take to apply for Applied Mathematics and Informatics program?'
    ],
    'answer': [
        'To enter the Bachelor\'s program in Applied Mathematics and Informatics, you can apply through Olympiads for school students or by taking entrance exams in Computer Science and Information Communication Technologies (minimum score: 75), Mathematics (minimum score: 75), and Russian Language (minimum score: 60). For further details, you can contact the program directly.',
        'You can find a link to all Bachelor\'s programs at HSE University here: https://www.hse.ru/education/msk/bachelor/',
        'The Bachelor\'s program in Mathematics costs 480,000 rubles per year, and the Bachelor\'s program in Applied Mathematics costs 430,000 rubles per year. Both of these programs fall within the budget of 600,000 rubles.',
        'The goal of the Bachelor\'s program in Mathematics is to provide comprehensive and modern fundamental mathematical training. The program aims to offer a wide range of mathematical sciences and applications to students, allowing them to choose a direction for their future careers in the world of intellectual professions. The program also prepares students who wish to continue their education after graduation to be sought after in the best international universities.',
        'In the educational program of Applied Mathematics, students participate in real projects related to mathematical and computer modeling, software development, and consulting in the development and implementation of modern information technologies and systems.',
        'In the educational program of Applied Mathematics, the minimum score needed in Mathematics for admission is 75.',
        "The Bachelor's program in Applied Mathematics and Informatics supports information processing through mathematical and software methods, enabling students to handle a wide range of scientific and technical problems.",
        'The purpose of the General Education subjects is to provide a broad-based education that includes humanities, social sciences, and natural sciences, which complement the specialized mathematical training.',
         "The goal of the Bachelor's program in Mathematics is to provide comprehensive and modern fundamental mathematical training. The program aims to offer a wide range of mathematical sciences and applications to students, allowing them to choose a direction for their future careers in the world of intellectual professions. The program also prepares students who wish to continue their education after graduation to be sought after in the best international universities.",
        'In the educational program of Applied Mathematics, starting from the 2nd year, students participate in real projects, both fundamental and applied. These projects include data processing and analysis for medicine and pharmacology, optimal structure calculations in biomechanics, ballistic design for space missions, design and implementation of information management systems for enterprises, banks, insurance companies, and more. Students get hands-on experience in various fields related to applied mathematics and information technology.',
        'In the educational program of Applied Mathematics, the minimum score needed in Mathematics for admission is 75.',
        "The Bachelor's program in Applied Mathematics prepares students to work in various fields, including mathematics in medicine, biomechanics, space missions, and enterprise management. The program equips students with the necessary skills to solve a wide range of scientific and engineering problems using modern mathematical, physical, and information technology achievements. Graduates can work as mathematicians, information systems developers, consultants in the development and implementation of modern information technologies and systems, and software engineers. They can also work as analysts in various fields.",
        'The purpose of the General Education subjects is to provide a broad-based education that includes humanities, social sciences, and natural sciences, which complement the specialized mathematical training.',
        'Graduates of the Applied Mathematics program can work in various fields such as mathematics in medicine, biomechanics, space missions, and enterprise management. The program equips students with skills to solve a wide range of scientific and engineering problems using modern mathematical, physical, and information technology achievements.',
        'Starting from the 2nd year, students participate in real projects, both fundamental and applied, including data processing and analysis for medicine and pharmacology, calculation of optimal structures in biomechanics, ballistic design of space missions, design and implementation of information and control systems for enterprises, banks, insurance companies, etc.',
        'The basis for the "Design" program at the School of Design at the National Research University Higher School of Economics is a practical-oriented approach. The program is developed by leading industry professionals and focuses on project thinking, fundamental knowledge of design and art history and theory, modern design technologies, and building a professional portfolio. Graduates of the program become in-demand specialists capable of conceptual and strategic thinking, solving a wide range of tasks, and leading creative teams.',
        'To enter the Bachelor\'s program in Applied Mathematics and Informatics, you can apply through Olympiads for school students or by taking entrance exams in Computer Science and Information Communication Technologies (minimum score: 75), Mathematics (minimum score: 75), and Russian Language (minimum score: 60). For further details, you can contact the program directly.',

    ],
    'contexts': [
        [
            'Вступительные испытания на Бакалаврская программа Компьютерные науки и анализ данных - Математика (минимальный балл: 65), Информатика и информационно-коммуникационные технологии (минимальный балл: 65) или Физика (минимальный балл: 65), Русский язык (минимальный балл: 60), Бакалаврская программа Математика для поступления на бакалаврскую программу «Математика» необходимо сдать ЕГЭ по 3 предметам: Математика (минимальный балл 75), Физика или информатика (минимальный балл 65), Русский язык (минимальный балл 60), для поступления на Бакалаврская программа Прикладная математика нужно сдать Физику (минимальный балл: 65) или Информатика и информационно-коммуникационные технологии (минимальный балл: 65), Математика (минимальный балл: 65), Русский язык (минимальный балл: 60), Состав вступительных испытаний и минимальные баллы для программы Прикладная Математика и Информатика, подтверждающие успешное прохождение вступительных испытаний: Информатика и информационно-коммуникационные технологии (минимальный балл: 75), Математика (минимальный балл: 75), Русский язык (минимальный балл: 60), Бакалаврская программа Прикладной анализ данных, Бакалаврская программа Совместный бакалавриат НИУ ВШЭ и ЦПМ...'
        ],
        [
            'With a wide range of Bachelor’s programmes and Master’s programmes, HSE attracts students from across Russia and the world. From secondary school to doctoral programmes, HSE offers education at all levels. Each year, the opportunities for education in English at HSE grow. HSE University offers nine English-taught undergraduate programmes. Four undergraduate programmes give students the opportunity to earn double or parallel degrees from HSE and the University of London with London School of Economics and Political Science serving as the lead college. There is also a double-degree programme with Kyung Hee University in Economics and Politics in Asia. Cсылка со всеми бакалаврскими программами: https://www.hse.ru/education/msk/bachelor/'
        ],
        [
            'Стоимость обучения на платных местах в 2024 году Бакалаврской программе Математика 480 000 руб. в год; Стоимость обучения на платных местах в 2024 году Бакалаврской программе Прикладная Математика 430 000 руб. в год, Стоимость обучения на платных местах в 2024 году Бакалаврской программе Прикладная Математика и Информатика 760 000 руб. в год; Стоимость обучения на платных местах в 2024 году на программе Бакалаврская программа Компьютерные науки и анализ данных 470 тысяч рублей в год.'
        ],
         [
            'Бакалаврская программа «Математика» дает всестороннюю современную фундаментальную математическую подготовку. На старших курсах индивидуальный учебный план позволяет уделить большое внимание специализации, выбрав ее из всего спектра актуальных направлений математики, смежных дисциплин или приложений. Благодаря этому выпускники, нацеленные на академическую карьеру, поступают в лучшие аспирантуры и магистратуры мира в области математики, физики и экономики, а остальные неизменно находят спрос в IT, финансах и других наукоемких приложениях. Тем не менее для успешного освоения программы важен интерес к математике как таковой, не обусловленный важностью математической подготовки для приложений. Цель программы — предоставить студентам, которые получают первое высшее образование, широкий спектр математических наук и приложений, чтобы в дальнейшем выбрать направление для деятельности в мире интеллектуальных профессий. Более того, абитуриенты, которые решат продолжить обучение после окончания программы, будут востребованы в лучших международных университетах.'
        ],
        [
            'Математическое и компьютерное моделирование, разработка программного обеспечения, консультирование по разработке и внедрению современных информационных технологий и систем, работа в качестве аналитиков в различных областях.'
        ],
        [
            'Без вступительных испытаний, либо право учитывать результат Олимпиады как максимально возможное количество баллов ЕГЭ (100 баллов) по общеобразовательному предмету. Состав вступительных испытаний и минимальные баллы для программы Прикладная Математика и Информатика: Математика (минимальный балл: 75), Русский язык (минимальный балл: 60), Информатика и информационно-коммуникационные технологии (минимальный балл: 75).'
        ],
        [
            'Математическое и компьютерное моделирование, разработка программного обеспечения, консультирование по разработке и внедрению современных информационных технологий и систем, работа в качестве аналитиков в различных областях.'
        ],
        [
            'Цель общеобразовательных предметов — предоставить широкую образовательную базу, которая включает гуманитарные, социальные и естественные науки, дополняющие специализированное математическое обучение.'
        ],
         [
            'Бакалаврская программа «Математика» дает всестороннюю современную фундаментальную математическую подготовку. На старших курсах индивидуальный учебный план позволяет уделить большое внимание специализации, выбрав ее из всего спектра актуальных направлений математики, смежных дисциплин или приложений. Благодаря этому выпускники, нацеленные на академическую карьеру, поступают в лучшие аспирантуры и магистратуры мира в области математики, физики и экономики, а остальные неизменно находят спрос в IT, финансах и других наукоемких приложениях. Тем не менее для успешного освоения программы важен интерес к математике как таковой, не обусловленный важностью математической подготовки для приложений. Цель программы — предоставить студентам, которые получают первое высшее образование, широкий спектр математических наук и приложений, чтобы в дальнейшем выбрать направление для деятельности в мире интеллектуальных профессий. Более того, абитуриенты, которые решат продолжить обучение после окончания программы, будут востребованы в лучших международных университетах.'
        ],
        [
            'Математическое и компьютерное моделирование, разработка программного обеспечения, консультирование по разработке и внедрению современных информационных технологий и систем, работа в качестве аналитиков в различных областях.'
        ],
        [
            'Без вступительных испытаний, либо право учитывать результат Олимпиады как максимально возможное количество баллов ЕГЭ (100 баллов) по общеобразовательному предмету. Состав вступительных испытаний и минимальные баллы для программы Прикладная Математика и Информатика: Математика (минимальный балл: 75), Русский язык (минимальный балл: 60), Информатика и информационно-коммуникационные технологии (минимальный балл: 75).'
        ],
        [
            'Математическое и компьютерное моделирование, разработка программного обеспечения, консультирование по разработке и внедрению современных информационных технологий и систем, работа в качестве аналитиков в различных областях.'
        ],
        [
            'Цель общеобразовательных предметов — предоставить широкую образовательную базу, которая включает гуманитарные, социальные и естественные науки, дополняющие специализированное математическое обучение.'
        ],
        [
            'Математическое и компьютерное моделирование, разработка программного обеспечения, консультирование по разработке и внедрению современных информационных технологий и систем, работа в качестве аналитиков в различных областях.'
        ],
        [
            'Математическое и компьютерное моделирование, разработка программного обеспечения, консультирование по разработке и внедрению современных информационных технологий и систем, работа в качестве аналитиков в различных областях.'
        ],
        [
            'Программа "Дизайн" в Высшей школе экономики разработана ведущими профессионалами отрасли и ориентирована на практическое обучение. Программа включает проектное мышление, фундаментальные знания истории и теории дизайна и искусства, современные технологии дизайна и создание профессионального портфолио. Выпускники программы становятся востребованными специалистами, способными к концептуальному и стратегическому мышлению, решению широкого круга задач и руководству творческими коллективами.'
        ],
        [
            'Состав вступительных испытаний и минимальные баллы для программы Прикладная Математика и Информатика, подтверждающие успешное прохождение вступительных испытаний: Информатика и информационно-коммуникационные технологии (минимальный балл: 75), Математика (минимальный балл: 75), Русский язык (минимальный балл: 60).'
        ]
    ],
    'ground_truth': [
        'You can enroll in the “Applied Mathematics and Informatics” program based on the results of: Olympiads for schoolchildren. Winners and prize-winners of some Olympiads for schoolchildren have the right to admission without entrance examinations, or the right to take into account the result of the Olympiad as the maximum number of Unified State Examination points (100 points) in a general education subject. Or based on the results of entrance tests Composition of entrance tests and minimum scores for the Applied Mathematics and Computer Science program, confirming successful completion of entrance tests: Computer Science and Information and Communication Technologies (minimum score: 75), Mathematics (minimum score: 75), Russian language (minimum score: 60)',
        'You can find a link to all programs: https://www.hse.ru/education/msk/bachelor/',
        'Bachelor\'s program Mathematics 480,000 rub. in year; Applied Mathematics 430,000 rub. per year, Bachelor\'s program Computer Science and Data Analysis 470 thousand rubles per year.',
        'The goal of the mathematical preparation program is to provide students with a comprehensive and modern fundamental mathematical education, allowing them to choose a direction for their future careers in intellectual professions and preparing them for further education at leading international universities.',
        'Students participate in real projects such as mathematical and computer modeling, software development, and consulting in the implementation of modern information technologies and systems.',
        'The minimum score needed in Mathematics for admission to the Applied Mathematics program is 75.',
        'Math and software support information processing by enabling students to handle a wide range of scientific and technical problems through mathematical and software methods.',
        'The purpose of the General Education Subject is to provide a broad-based education that includes humanities, social sciences, and natural sciences, complementing specialized mathematical training.',
        "The goal of the mathematical preparation program is to provide students with a wide range of mathematical sciences and applications, allowing them to choose a direction for their career in the world of intellectual professions.",
    "Students participate in real projects such as data processing and analysis for medicine and pharmacology, calculation of optimal structures in biomechanics, ballistic design of space missions, design and implementation of information and control systems for enterprises, banks, insurance companies, etc.",
    "The minimum score needed in Mathematics for admission to the Applied Mathematics and Informatics program is 75 points.",
    "Math and software support information processing in medicine, biomechanics, space missions, and enterprise management through data processing and analysis, calculation of optimal structures, ballistic design of space missions, and the design and implementation of information management systems for enterprises, banks, insurance companies, etc.",
    "The purpose of the General Education Subject in the 'Applied Mathematics and Computer Science' program is to develop skills in data analysis, research in computer science, and software engineering. It aims to prepare students for careers as data scientists, analysts, researchers, and software engineers.",
    'Graduates of the Applied Mathematics program can work in various fields such as mathematics in medicine, biomechanics, space missions, and enterprise management. The program equips students with skills to solve a wide range of scientific and engineering problems using modern mathematical, physical, and information technology achievements.',
    "Starting from the 2nd year, students participate in real projects, both fundamental and applied, including data processing and analysis for medicine and pharmacology, calculation of optimal structures in biomechanics, ballistic design of space missions, design and implementation of information and control systems for enterprises, banks, insurance companies, etc.",
    "The basis for the 'Design' program at the School of Design at the National Research University Higher School of Economics is a practical-oriented approach. The program is developed by leading industry professionals and focuses on project thinking, fundamental knowledge of design and art history and theory, modern design technologies, and building a professional portfolio. Graduates of the program become in-demand specialists capable of conceptual and strategic thinking, solving a wide range of tasks, and leading creative teams.",
    "You can enroll in the 'Applied Mathematics and Informatics' program based on the results of: Olympiads for schoolchildren. Winners and prize-winners of some Olympiads for schoolchildren have the right to admission without entrance examinations, or the right to take into account the result of the Olympiad as the maximum number of Unified State Examination points (100 points) in a general education subject. Or based on the results of entrance tests Composition of entrance tests and minimum scores for the Applied Mathematics and Computer Science program, confirming successful completion of entrance tests: Computer Science and Information and Communication Technologies (minimum score: 75), Mathematics (minimum score: 75), Russian language (minimum score: 60)"
    ]
}

# %%
import pandas as pd

# %%
from datasets import Dataset
from ragas.metrics import faithfulness, answer_relevancy, context_precision, answer_similarity, answer_correctness, context_recall
from ragas import evaluate

dataset = Dataset.from_dict(data_samples)

score = evaluate(dataset, metrics=[faithfulness, answer_relevancy, context_precision, answer_similarity, context_recall, answer_correctness])

df = score.to_pandas()
df
# Out:
# Evaluating:   0%|          | 0/102 [00:00<?, ?it/s]
#                                              question  \
# 0   What exams should I take to apply for Applied ...
# 1     Send me the link to the page with all programs.
# 2   My budget is 600,000 rubles. Can you recommend...
# 3   What is the goal of the mathematical preparati...
# 4   What kind of real projects do students partici...
# 5   What is the minimum score needed in Mathematic...
# 6   How do math and software support information p...
# 7   What is the purpose of the General Education S...
# 8   What is the goal of the mathematical preparati...
# 9   What kind of real projects do students partici...
# 10  What is the minimum score needed in Mathematic...
# 11  How do math and software support information p...
# 12  What is the purpose of the General Education S...
# 13  What fields can students work in after complet...
# 14  What real-world problems do students solve in ...
# ...

# %%
df.columns
# Out:
# Index(['question', 'answer', 'contexts', 'ground_truth', 'faithfulness',
#        'answer_relevancy', 'context_precision', 'answer_similarity',
#        'context_recall', 'answer_correctness'],
#       dtype='object')

# %%
df[['faithfulness',
       'answer_relevancy', 'context_precision', 'answer_similarity',
       'context_recall', 'answer_correctness']].mean()
# Out:
# faithfulness          0.722222
# answer_relevancy      0.884930
# context_precision     1.000000
# answer_similarity     0.966435
# context_recall        0.777778
# answer_correctness    0.672164
# dtype: float64
